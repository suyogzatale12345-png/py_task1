# %% [markdown]
# # Count() Methods

# %%
s1 = "I like Movie , My favorite movie is KGF"

z = s1.count("movie")

print(z)
# Out:
# 1

# %%
str = "This is Count Methods Example"

a = str.count("i")

print(a)
# Out:
# 2

# %%
str = "This is string "

a = str.count("i")

print(f"this is string = {a}")
# Out:
# this is string = 3
