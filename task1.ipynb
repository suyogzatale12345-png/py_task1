# %% [markdown]
# # Upper() Methods

# %%
abc = " I m going to Wardha"
print(abc)

x = abc.upper()

print(x)
# Out:
#  I m going to Wardha
#  I M GOING TO WARDHA

# %%
abc = " I m going to Wardha"


x = abc.upper()

print(x)
# Out:
#  I M GOING TO WARDHA

# %%
abc = " I m going to Wardha"
print(abc)
print('-')
x = abc.upper()

print(x)
# Out:
#  I m going to Wardha
# -
#  I M GOING TO WARDHA

# %%
print(f"this is noraml text ={abc}")
abcUpper = abc.upper()
print('-')
print(f"this is upper text = {abcUpper}")
print('-')
print(f"this is noraml text = {abc}")
# Out:
# this is noraml text = I m going to Wardha
# -
# this is upper text =  I M GOING TO WARDHA
# -
# this is noraml text =  I m going to Wardha
