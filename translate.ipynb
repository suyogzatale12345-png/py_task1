# %% [markdown]
# # Translate() Methods

# %%
d1 = {83:  80}
txt = "Hello MOdi Ji!"
print(txt.translate(d1))
# Out:
# Hello MOdi Ji!

# %%
md = {83:  80}
txt = "Hello Sam!"
print(txt.translate(md))
# Out:
# Hello Pam!

# %%
abc ={80: 85}

text = "Welcome to my world"

print(text.translate(abc))
# Out:
# Welcome to my world

# %%
abc ={10: 20}

text = "Welcome to my world"

print(text.translate(abc))
# Out:
# Welcome to my world
