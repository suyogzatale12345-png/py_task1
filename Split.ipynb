# %% [markdown]
# # Split() Methods

# %%
xyz = "welcome to the mungle"

crazy =xyz.split()

print(crazy)
# Out:
# ['welcome', 'to', 'the', 'mungle']

# %%
xyz = "welcome to the jungle"

crazy =xyz.split()

print(crazy)
# Out:
# ['welcome', 'to', 'the', 'jungle']

# %%
xyz = "welcome to the space"

crazy =xyz.split()

print(crazy)
# Out:
# ['welcome', 'to', 'the', 'space']

# %%
xyz = "welcome to the Narak"

crazy =xyz.split()

print(crazy)
# Out:
# ['welcome', 'to', 'the', 'Narak']
