# %% [markdown]
# # Center() Methods

# %%
a = "Apple"

b = a.center(10,"o")
print(b)
# Out:
# ooAppleooo

# %%
b = "Banana"
d = b.center(5,"n")
print(d)
# Out:
# Banana

# %%
ab = "i love Mango"

ac = ab.center(1,"o")

print(ac)
# Out:
# i love Mango
