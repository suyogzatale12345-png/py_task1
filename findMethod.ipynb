# %% [markdown]
# # Find() Methods

# %%
a = "welcome to the mumbai"

b = a.find("mumbai")

print(b)
# Out:
# 15

# %%
A = "Hellow, Welcome in the hell"

B = A.find("hell")
print(B)
# Out:
# 23

# %%
st = "I m visit Goa"

sr = st.find("m")
print(sr)
# Out:
# 2

# %%
ae = "i love wardha "
aw = ae.find("wardha")
print(aw)
# Out:
# 7
