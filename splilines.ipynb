# %% [markdown]
# # splitLines () Methods

# %%
abc = "my fovorite web series\nwelcome babu bhaiya "

a = abc.splitlines()

print(a)
# Out:
# ['my fovorite web series', 'welcome babu bhaiya ']

# %%
abc = "my fovorite web series is jamana paar\nwelcome babu bhaiya "

a = abc.splitlines()

print(a)
# Out:
# ['my fovorite web series is jamana paar', 'welcome babu bhaiya ']

# %%
abc = "my fovorite song is har kisi ko\nwelcome babu bhaiya "

a = abc.splitlines()

print(a)
# Out:
# ['my fovorite song is har kisi ko', 'welcome babu bhaiya ']

# %%
abc = "my fovorite song is har kisi ko\nwelcome babu bhaiya "

a = abc.splitlines()

print(a)
# Out:
# ['my fovorite song is har kisi ko', 'welcome babu bhaiya ']
